# %% [markdown]
# # 프로젝트 : Segmentation map으로 도로 이미지 만들기

# %%
# 모듈 import
import tensorflow as tf
from tensorflow.keras import layers, Input, Model
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import time

print(np.__version__)
print(tf.__version__)
# Out:
# 1.21.4
# 2.6.0

# %% [markdown]
# 1. 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해 주세요.
# (어떠한 방법을 사용했는지 적어주세요.)
# 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해 주세요.
# 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
# 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.
# 5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %% [markdown]
# # 1. 데이터 준비하기

# %%
data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
# 이미지 확인
plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 이미지 shape 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
# (256, 256, 3) 크기의 2개의 이미지로 분할해서 사용합니다.

import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
# 이미지 분리
f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

# Augmentation 적용
@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용
def apply_augmentation(sketch, colored):
    # 두 이미지를 채널 축으로 연결 (3채널인 경우 6채널로 변환)
    stacked = tf.concat([sketch, colored], axis=-1)

    _pad = tf.constant([[30,30],[30,30],[0,0]])
    
    # 50%의 확률로 Refection padding 또는 constant padding 적용
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    # 임의로 crop
    out = image.random_crop(padded, size=[256, 256, 6])

    # 50% 확률로 좌우상하 반전
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)

    # 50% 확률로 회전
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)

    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

# 학습 노드에서 sketch와 colored 순서가 다름에 주의
def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return colored, sketch

# %%
train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# # 2. Generator 구성하기

# %%
# Encoder
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

# %%
# Decoder   
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
# U-Net Generator
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        # Encoder의 마지막 출력은 Decoder로 직접 입력되므로 Skip Connection에서 제외
        features = features[:-1]

        # feature의 역순으로 Skip Connection
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat]) # 가장 마지막 축(Channel) 기준으로 연결
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# # 3. Discriminator 구성하기

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            # 1 만큼 ZeroPadding
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
# 임의 테스트
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# # 4. 학습 및 테스트하기

# %%
# Loss Function
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
# Optimizer
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
# 학습 가중치 업데이트 함수
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
# 10 epoch 훈련
EPOCHS = 10

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:1.1682
# L1_loss:0.2352
# Discriminator_loss:1.6920
#
# EPOCH[1] - STEP[20]
# Generator_loss:0.7023
# L1_loss:0.1771
# Discriminator_loss:1.3954
#
# EPOCH[1] - STEP[30]
# Generator_loss:0.6601
# L1_loss:0.2197
# Discriminator_loss:1.3712
#
# EPOCH[1] - STEP[40]
# Generator_loss:0.7043
# L1_loss:0.1945
# Discriminator_loss:1.3734
#
# EPOCH[1] - STEP[50]
# Generator_loss:0.6711
# L1_loss:0.2009
# Discriminator_loss:1.4331
#
# EPOCH[1] - STEP[60]
# Generator_loss:0.6342
# L1_loss:0.2007
# Discriminator_loss:1.3686
#
# EPOCH[1] - STEP[70]
# Generator_loss:0.8028
# L1_loss:0.2148
# Discriminator_loss:1.3031
#
# EPOCH[1] - STEP[80]
# Generator_loss:0.8345
# L1_loss:0.1579
# Discriminator_loss:1.2635
#
# EPOCH[1] - STEP[90]
# Generator_loss:0.8874
# L1_loss:0.2094
# Discriminator_loss:1.1665
#
# EPOCH[1] - STEP[100]
# Generator_loss:0.9149
# L1_loss:0.2032
# Discriminator_loss:1.1190
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.1371
# L1_loss:0.2138
# Discriminator_loss:1.1065
#
# EPOCH[1] - STEP[120]
# Generator_loss:0.8934
# L1_loss:0.1623
# Discriminator_loss:1.1187
#
# EPOCH[1] - STEP[130]
# Generator_loss:0.7601
# L1_loss:0.2003
# Discriminator_loss:1.1949
#
# EPOCH[1] - STEP[140]
# Generator_loss:0.8452
# L1_loss:0.1635
# Discriminator_loss:1.1781
#
# EPOCH[1] - STEP[150]
# Generator_loss:0.6848
# L1_loss:0.1841
# Discriminator_loss:1.2844
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.1728
# L1_loss:0.2054
# Discriminator_loss:1.1310
#
# EPOCH[1] - STEP[170]
# Generator_loss:0.9184
# L1_loss:0.1746
# Discriminator_loss:1.1866
#
# EPOCH[1] - STEP[180]
# Generator_loss:0.7896
# L1_loss:0.1639
# Discriminator_loss:1.1517
#
# EPOCH[1] - STEP[190]
# Generator_loss:1.1175
# L1_loss:0.1831
# Discriminator_loss:0.9122
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.5163
# L1_loss:0.1514
# Discriminator_loss:1.8820
#
# EPOCH[1] - STEP[210]
# Generator_loss:1.0534
# L1_loss:0.2033
# Discriminator_loss:1.1310
#
# EPOCH[1] - STEP[220]
# Generator_loss:0.5717
# L1_loss:0.1596
# Discriminator_loss:1.3282
#
# EPOCH[1] - STEP[230]
# Generator_loss:1.1680
# L1_loss:0.1578
# Discriminator_loss:1.4907
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.3721
# L1_loss:0.2009
# Discriminator_loss:0.8629
#
# EPOCH[1] - STEP[250]
# Generator_loss:1.0131
# L1_loss:0.1815
# Discriminator_loss:1.0973
#
# EPOCH[2] - STEP[10]
# Generator_loss:2.3577
# L1_loss:0.1616
# Discriminator_loss:1.7084
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.2077
# L1_loss:0.1812
# Discriminator_loss:0.9854
#
# EPOCH[2] - STEP[30]
# Generator_loss:0.5558
# L1_loss:0.1671
# Discriminator_loss:1.4381
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.6930
# L1_loss:0.2018
# Discriminator_loss:0.5782
#
# EPOCH[2] - STEP[50]
# Generator_loss:0.6701
# L1_loss:0.1541
# Discriminator_loss:1.5612
#
# EPOCH[2] - STEP[60]
# Generator_loss:0.6150
# L1_loss:0.1678
# Discriminator_loss:1.0345
#
# EPOCH[2] - STEP[70]
# Generator_loss:0.5161
# L1_loss:0.2302
# Discriminator_loss:1.9587
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.8474
# L1_loss:0.1877
# Discriminator_loss:1.1571
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.9256
# L1_loss:0.1964
# Discriminator_loss:1.1324
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.2564
# L1_loss:0.1722
# Discriminator_loss:0.9366
#
# EPOCH[2] - STEP[110]
# Generator_loss:0.7997
# L1_loss:0.2018
# Discriminator_loss:1.0107
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.0106
# L1_loss:0.1820
# Discriminator_loss:0.8478
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.0431
# L1_loss:0.1696
# Discriminator_loss:0.9098
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.7745
# L1_loss:0.2009
# Discriminator_loss:0.6874
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.1755
# L1_loss:0.1751
# Discriminator_loss:0.9031
#
# EPOCH[2] - STEP[160]
# Generator_loss:2.0945
# L1_loss:0.2148
# Discriminator_loss:0.7899
#
# EPOCH[2] - STEP[170]
# Generator_loss:2.1030
# L1_loss:0.1497
# Discriminator_loss:1.1434
#
# EPOCH[2] - STEP[180]
# Generator_loss:0.9299
# L1_loss:0.1568
# Discriminator_loss:0.8536
#
# EPOCH[2] - STEP[190]
# Generator_loss:0.4632
# L1_loss:0.2078
# Discriminator_loss:1.5133
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.9265
# L1_loss:0.1609
# Discriminator_loss:1.1056
#
# EPOCH[2] - STEP[210]
# Generator_loss:1.9835
# L1_loss:0.2992
# Discriminator_loss:0.4278
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.6949
# L1_loss:0.1861
# Discriminator_loss:0.4745
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.8768
# L1_loss:0.1847
# Discriminator_loss:1.4482
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.1289
# L1_loss:0.2150
# Discriminator_loss:0.8975
#
# EPOCH[2] - STEP[250]
# Generator_loss:2.0244
# L1_loss:0.2027
# Discriminator_loss:0.5730
#
# EPOCH[3] - STEP[10]
# Generator_loss:2.1612
# L1_loss:0.1904
# Discriminator_loss:0.6598
#
# EPOCH[3] - STEP[20]
# Generator_loss:2.3538
# L1_loss:0.1797
# Discriminator_loss:1.0551
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.8064
# L1_loss:0.2164
# Discriminator_loss:0.3604
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.9371
# L1_loss:0.1583
# Discriminator_loss:0.5072
#
# EPOCH[3] - STEP[50]
# Generator_loss:2.3421
# L1_loss:0.1559
# Discriminator_loss:0.5418
#
# EPOCH[3] - STEP[60]
# Generator_loss:1.8178
# L1_loss:0.1773
# Discriminator_loss:0.4909
#
# EPOCH[3] - STEP[70]
# Generator_loss:1.5457
# L1_loss:0.1549
# Discriminator_loss:0.5539
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.9562
# L1_loss:0.1695
# Discriminator_loss:0.9034
#
# EPOCH[3] - STEP[90]
# Generator_loss:1.0320
# L1_loss:0.1382
# Discriminator_loss:0.8097
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.9742
# L1_loss:0.1543
# Discriminator_loss:0.7209
#
# EPOCH[3] - STEP[110]
# Generator_loss:2.4121
# L1_loss:0.2049
# Discriminator_loss:0.4391
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.4428
# L1_loss:0.1868
# Discriminator_loss:0.6913
#
# EPOCH[3] - STEP[130]
# Generator_loss:2.6991
# L1_loss:0.2194
# Discriminator_loss:0.2048
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.8090
# L1_loss:0.1632
# Discriminator_loss:0.3101
#
# EPOCH[3] - STEP[150]
# Generator_loss:3.7627
# L1_loss:0.1715
# Discriminator_loss:0.5617
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.1497
# L1_loss:0.1976
# Discriminator_loss:0.6281
#
# EPOCH[3] - STEP[170]
# Generator_loss:1.0163
# L1_loss:0.2011
# Discriminator_loss:0.7088
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.2229
# L1_loss:0.1814
# Discriminator_loss:0.4937
#
# EPOCH[3] - STEP[190]
# Generator_loss:2.3218
# L1_loss:0.1636
# Discriminator_loss:0.5186
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.9075
# L1_loss:0.2061
# Discriminator_loss:0.3303
#
# EPOCH[3] - STEP[210]
# Generator_loss:2.4264
# L1_loss:0.1667
# Discriminator_loss:0.5086
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.6038
# L1_loss:0.2120
# Discriminator_loss:0.4989
#
# EPOCH[3] - STEP[230]
# Generator_loss:1.4336
# L1_loss:0.1808
# Discriminator_loss:0.5219
#
# EPOCH[3] - STEP[240]
# Generator_loss:2.1287
# L1_loss:0.2092
# Discriminator_loss:0.3914
#
# EPOCH[3] - STEP[250]
# Generator_loss:0.9796
# L1_loss:0.1818
# Discriminator_loss:1.1021
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.8162
# L1_loss:0.1788
# Discriminator_loss:0.5546
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.5222
# L1_loss:0.1977
# Discriminator_loss:0.8352
#
# EPOCH[4] - STEP[30]
# Generator_loss:1.6299
# L1_loss:0.1637
# Discriminator_loss:1.3071
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.1106
# L1_loss:0.1777
# Discriminator_loss:0.6392
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.3611
# L1_loss:0.1991
# Discriminator_loss:0.6855
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.0714
# L1_loss:0.2126
# Discriminator_loss:0.5452
#
# EPOCH[4] - STEP[70]
# Generator_loss:2.6125
# L1_loss:0.1682
# Discriminator_loss:0.4635
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.1900
# L1_loss:0.1691
# Discriminator_loss:0.5918
#
# EPOCH[4] - STEP[90]
# Generator_loss:2.7088
# L1_loss:0.2128
# Discriminator_loss:0.2766
#
# EPOCH[4] - STEP[100]
# Generator_loss:2.8578
# L1_loss:0.1765
# Discriminator_loss:0.4225
#
# EPOCH[4] - STEP[110]
# Generator_loss:0.7537
# L1_loss:0.1738
# Discriminator_loss:0.8882
#
# EPOCH[4] - STEP[120]
# Generator_loss:2.3875
# L1_loss:0.1941
# Discriminator_loss:0.9072
#
# EPOCH[4] - STEP[130]
# Generator_loss:0.7022
# L1_loss:0.1731
# Discriminator_loss:0.9693
#
# EPOCH[4] - STEP[140]
# Generator_loss:3.0270
# L1_loss:0.1626
# Discriminator_loss:0.5486
#
# EPOCH[4] - STEP[150]
# Generator_loss:1.5865
# L1_loss:0.1588
# Discriminator_loss:0.7451
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.7812
# L1_loss:0.1606
# Discriminator_loss:0.8572
#
# EPOCH[4] - STEP[170]
# Generator_loss:2.1570
# L1_loss:0.1545
# Discriminator_loss:0.3200
#
# EPOCH[4] - STEP[180]
# Generator_loss:2.9236
# L1_loss:0.2033
# Discriminator_loss:1.1613
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.9092
# L1_loss:0.2599
# Discriminator_loss:0.4296
#
# EPOCH[4] - STEP[200]
# Generator_loss:2.6471
# L1_loss:0.1950
# Discriminator_loss:0.7988
#
# EPOCH[4] - STEP[210]
# Generator_loss:1.1644
# L1_loss:0.1830
# Discriminator_loss:0.4706
#
# EPOCH[4] - STEP[220]
# Generator_loss:2.0259
# L1_loss:0.1739
# Discriminator_loss:0.5029
#
# EPOCH[4] - STEP[230]
# Generator_loss:0.9017
# L1_loss:0.1994
# Discriminator_loss:1.3597
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.2703
# L1_loss:0.1809
# Discriminator_loss:0.7950
#
# EPOCH[4] - STEP[250]
# Generator_loss:0.9906
# L1_loss:0.1821
# Discriminator_loss:0.7366
#
# EPOCH[5] - STEP[10]
# Generator_loss:2.2827
# L1_loss:0.1593
# Discriminator_loss:1.2316
#
# EPOCH[5] - STEP[20]
# Generator_loss:2.1381
# L1_loss:0.1867
# Discriminator_loss:0.3919
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.1203
# L1_loss:0.1788
# Discriminator_loss:1.1081
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.3084
# L1_loss:0.2067
# Discriminator_loss:0.9767
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.3311
# L1_loss:0.1879
# Discriminator_loss:0.4962
#
# EPOCH[5] - STEP[60]
# Generator_loss:2.5337
# L1_loss:0.1431
# Discriminator_loss:0.5001
#
# EPOCH[5] - STEP[70]
# Generator_loss:1.6910
# L1_loss:0.2008
# Discriminator_loss:0.3785
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.4098
# L1_loss:0.1889
# Discriminator_loss:0.5028
#
# EPOCH[5] - STEP[90]
# Generator_loss:0.7342
# L1_loss:0.2194
# Discriminator_loss:0.9434
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.2751
# L1_loss:0.1957
# Discriminator_loss:0.7594
#
# EPOCH[5] - STEP[110]
# Generator_loss:2.1746
# L1_loss:0.1748
# Discriminator_loss:0.8875
#
# EPOCH[5] - STEP[120]
# Generator_loss:0.9040
# L1_loss:0.1786
# Discriminator_loss:1.3456
#
# EPOCH[5] - STEP[130]
# Generator_loss:1.4889
# L1_loss:0.1772
# Discriminator_loss:0.9164
#
# EPOCH[5] - STEP[140]
# Generator_loss:0.5148
# L1_loss:0.1623
# Discriminator_loss:1.2649
#
# EPOCH[5] - STEP[150]
# Generator_loss:0.9764
# L1_loss:0.1888
# Discriminator_loss:0.7308
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.1902
# L1_loss:0.1907
# Discriminator_loss:0.7276
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.1220
# L1_loss:0.2096
# Discriminator_loss:0.4944
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.8257
# L1_loss:0.1787
# Discriminator_loss:0.7526
#
# EPOCH[5] - STEP[190]
# Generator_loss:0.2135
# L1_loss:0.2119
# Discriminator_loss:2.0838
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.1626
# L1_loss:0.1605
# Discriminator_loss:0.7837
#
# EPOCH[5] - STEP[210]
# Generator_loss:3.2621
# L1_loss:0.1819
# Discriminator_loss:0.9410
#
# EPOCH[5] - STEP[220]
# Generator_loss:1.1141
# L1_loss:0.1890
# Discriminator_loss:0.7633
#
# EPOCH[5] - STEP[230]
# Generator_loss:0.6084
# L1_loss:0.1606
# Discriminator_loss:1.4992
#
# EPOCH[5] - STEP[240]
# Generator_loss:0.4325
# L1_loss:0.2212
# Discriminator_loss:1.2925
#
# EPOCH[5] - STEP[250]
# Generator_loss:1.9170
# L1_loss:0.1613
# Discriminator_loss:1.6950
#
# EPOCH[6] - STEP[10]
# Generator_loss:0.4689
# L1_loss:0.2445
# Discriminator_loss:1.0958
#
# EPOCH[6] - STEP[20]
# Generator_loss:0.8588
# L1_loss:0.2015
# Discriminator_loss:0.7433
#
# EPOCH[6] - STEP[30]
# Generator_loss:0.3753
# L1_loss:0.1849
# Discriminator_loss:1.9186
#
# EPOCH[6] - STEP[40]
# Generator_loss:1.7272
# L1_loss:0.1916
# Discriminator_loss:1.1642
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.1119
# L1_loss:0.1511
# Discriminator_loss:0.5862
#
# EPOCH[6] - STEP[60]
# Generator_loss:1.6179
# L1_loss:0.1770
# Discriminator_loss:1.3473
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.3427
# L1_loss:0.1899
# Discriminator_loss:1.4235
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.3813
# L1_loss:0.1705
# Discriminator_loss:0.4503
#
# EPOCH[6] - STEP[90]
# Generator_loss:0.8524
# L1_loss:0.1787
# Discriminator_loss:0.6905
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.5117
# L1_loss:0.2056
# Discriminator_loss:0.8328
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.0245
# L1_loss:0.2024
# Discriminator_loss:0.6818
#
# EPOCH[6] - STEP[120]
# Generator_loss:0.7513
# L1_loss:0.1979
# Discriminator_loss:0.8358
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.3794
# L1_loss:0.2190
# Discriminator_loss:0.5679
#
# EPOCH[6] - STEP[140]
# Generator_loss:2.0364
# L1_loss:0.1871
# Discriminator_loss:0.9196
#
# EPOCH[6] - STEP[150]
# Generator_loss:2.1052
# L1_loss:0.1511
# Discriminator_loss:1.4764
#
# EPOCH[6] - STEP[160]
# Generator_loss:0.2361
# L1_loss:0.1739
# Discriminator_loss:2.2836
#
# EPOCH[6] - STEP[170]
# Generator_loss:2.6489
# L1_loss:0.1663
# Discriminator_loss:0.4402
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.0381
# L1_loss:0.1943
# Discriminator_loss:1.1118
#
# EPOCH[6] - STEP[190]
# Generator_loss:0.6256
# L1_loss:0.1811
# Discriminator_loss:0.9750
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.7672
# L1_loss:0.1805
# Discriminator_loss:0.6524
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.9351
# L1_loss:0.1641
# Discriminator_loss:1.0872
#
# EPOCH[6] - STEP[220]
# Generator_loss:0.9345
# L1_loss:0.1951
# Discriminator_loss:0.9733
#
# EPOCH[6] - STEP[230]
# Generator_loss:0.8763
# L1_loss:0.2209
# Discriminator_loss:0.6640
#
# EPOCH[6] - STEP[240]
# Generator_loss:1.6934
# L1_loss:0.1573
# Discriminator_loss:0.4045
#
# EPOCH[6] - STEP[250]
# Generator_loss:2.3673
# L1_loss:0.1779
# Discriminator_loss:1.1424
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.9417
# L1_loss:0.1778
# Discriminator_loss:1.0969
#
# EPOCH[7] - STEP[20]
# Generator_loss:1.0677
# L1_loss:0.1570
# Discriminator_loss:0.6897
#
# EPOCH[7] - STEP[30]
# Generator_loss:2.3966
# L1_loss:0.1746
# Discriminator_loss:0.6009
#
# EPOCH[7] - STEP[40]
# Generator_loss:1.2028
# L1_loss:0.1774
# Discriminator_loss:0.5004
#
# EPOCH[7] - STEP[50]
# Generator_loss:1.6307
# L1_loss:0.1635
# Discriminator_loss:0.4821
#
# EPOCH[7] - STEP[60]
# Generator_loss:2.6328
# L1_loss:0.1873
# Discriminator_loss:0.3195
#
# EPOCH[7] - STEP[70]
# Generator_loss:1.0878
# L1_loss:0.1661
# Discriminator_loss:1.8857
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.0836
# L1_loss:0.1865
# Discriminator_loss:0.6280
#
# EPOCH[7] - STEP[90]
# Generator_loss:2.3523
# L1_loss:0.1568
# Discriminator_loss:2.4011
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.2748
# L1_loss:0.1791
# Discriminator_loss:0.9851
#
# EPOCH[7] - STEP[110]
# Generator_loss:0.4901
# L1_loss:0.1594
# Discriminator_loss:1.1929
#
# EPOCH[7] - STEP[120]
# Generator_loss:2.3943
# L1_loss:0.1804
# Discriminator_loss:1.3395
#
# EPOCH[7] - STEP[130]
# Generator_loss:2.0798
# L1_loss:0.2370
# Discriminator_loss:0.3604
#
# EPOCH[7] - STEP[140]
# Generator_loss:0.6221
# L1_loss:0.1797
# Discriminator_loss:2.2365
#
# EPOCH[7] - STEP[150]
# Generator_loss:1.1375
# L1_loss:0.1824
# Discriminator_loss:1.1558
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.6351
# L1_loss:0.1896
# Discriminator_loss:1.0747
#
# EPOCH[7] - STEP[170]
# Generator_loss:1.8543
# L1_loss:0.1781
# Discriminator_loss:0.4905
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.7785
# L1_loss:0.2042
# Discriminator_loss:0.5481
#
# EPOCH[7] - STEP[190]
# Generator_loss:0.7937
# L1_loss:0.1822
# Discriminator_loss:0.8580
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.2423
# L1_loss:0.1545
# Discriminator_loss:2.0831
#
# EPOCH[7] - STEP[210]
# Generator_loss:1.7976
# L1_loss:0.1616
# Discriminator_loss:0.6214
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.0166
# L1_loss:0.1677
# Discriminator_loss:1.0271
#
# EPOCH[7] - STEP[230]
# Generator_loss:0.9986
# L1_loss:0.1775
# Discriminator_loss:1.3155
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.7145
# L1_loss:0.1762
# Discriminator_loss:1.7061
#
# EPOCH[7] - STEP[250]
# Generator_loss:0.9010
# L1_loss:0.1778
# Discriminator_loss:0.6879
#
# EPOCH[8] - STEP[10]
# Generator_loss:1.0068
# L1_loss:0.1529
# Discriminator_loss:1.2368
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.3941
# L1_loss:0.1930
# Discriminator_loss:0.4922
#
# EPOCH[8] - STEP[30]
# Generator_loss:1.0027
# L1_loss:0.1931
# Discriminator_loss:0.6982
#
# EPOCH[8] - STEP[40]
# Generator_loss:0.8725
# L1_loss:0.1777
# Discriminator_loss:0.7638
#
# EPOCH[8] - STEP[50]
# Generator_loss:2.1706
# L1_loss:0.2007
# Discriminator_loss:0.3522
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.2194
# L1_loss:0.1848
# Discriminator_loss:0.9630
#
# EPOCH[8] - STEP[70]
# Generator_loss:1.2671
# L1_loss:0.1338
# Discriminator_loss:0.8373
#
# EPOCH[8] - STEP[80]
# Generator_loss:1.5979
# L1_loss:0.1861
# Discriminator_loss:0.4802
#
# EPOCH[8] - STEP[90]
# Generator_loss:1.9387
# L1_loss:0.1562
# Discriminator_loss:0.8264
#
# EPOCH[8] - STEP[100]
# Generator_loss:2.2913
# L1_loss:0.1713
# Discriminator_loss:0.9135
#
# EPOCH[8] - STEP[110]
# Generator_loss:0.8375
# L1_loss:0.1842
# Discriminator_loss:2.5033
#
# EPOCH[8] - STEP[120]
# Generator_loss:2.9053
# L1_loss:0.1613
# Discriminator_loss:1.5766
#
# EPOCH[8] - STEP[130]
# Generator_loss:0.5704
# L1_loss:0.1539
# Discriminator_loss:1.6798
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.5695
# L1_loss:0.1645
# Discriminator_loss:1.3756
#
# EPOCH[8] - STEP[150]
# Generator_loss:2.3549
# L1_loss:0.1990
# Discriminator_loss:0.2966
#
# EPOCH[8] - STEP[160]
# Generator_loss:0.8007
# L1_loss:0.1738
# Discriminator_loss:1.1279
#
# EPOCH[8] - STEP[170]
# Generator_loss:2.3087
# L1_loss:0.1630
# Discriminator_loss:0.9797
#
# EPOCH[8] - STEP[180]
# Generator_loss:1.6983
# L1_loss:0.1928
# Discriminator_loss:0.2900
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.1026
# L1_loss:0.1752
# Discriminator_loss:0.9094
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.3094
# L1_loss:0.1947
# Discriminator_loss:0.4675
#
# EPOCH[8] - STEP[210]
# Generator_loss:2.0895
# L1_loss:0.2011
# Discriminator_loss:0.2569
#
# EPOCH[8] - STEP[220]
# Generator_loss:2.0698
# L1_loss:0.1679
# Discriminator_loss:0.4392
#
# EPOCH[8] - STEP[230]
# Generator_loss:1.1852
# L1_loss:0.1733
# Discriminator_loss:2.1422
#
# EPOCH[8] - STEP[240]
# Generator_loss:1.5159
# L1_loss:0.1505
# Discriminator_loss:0.5942
#
# EPOCH[8] - STEP[250]
# Generator_loss:1.3409
# L1_loss:0.2055
# Discriminator_loss:0.5253
#
# EPOCH[9] - STEP[10]
# Generator_loss:1.1028
# L1_loss:0.1735
# Discriminator_loss:0.6364
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.2983
# L1_loss:0.1721
# Discriminator_loss:1.4850
#
# EPOCH[9] - STEP[30]
# Generator_loss:1.5853
# L1_loss:0.2249
# Discriminator_loss:0.4478
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.0808
# L1_loss:0.1818
# Discriminator_loss:0.8151
#
# EPOCH[9] - STEP[50]
# Generator_loss:1.4820
# L1_loss:0.2172
# Discriminator_loss:0.4759
#
# EPOCH[9] - STEP[60]
# Generator_loss:1.0803
# L1_loss:0.1844
# Discriminator_loss:0.5911
#
# EPOCH[9] - STEP[70]
# Generator_loss:0.6889
# L1_loss:0.1995
# Discriminator_loss:0.9895
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.5477
# L1_loss:0.1919
# Discriminator_loss:0.5781
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.4420
# L1_loss:0.2378
# Discriminator_loss:0.3541
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.2507
# L1_loss:0.2197
# Discriminator_loss:0.4293
#
# EPOCH[9] - STEP[110]
# Generator_loss:1.1814
# L1_loss:0.1723
# Discriminator_loss:0.7331
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.5125
# L1_loss:0.1765
# Discriminator_loss:0.5032
#
# EPOCH[9] - STEP[130]
# Generator_loss:1.3613
# L1_loss:0.1967
# Discriminator_loss:0.8310
#
# EPOCH[9] - STEP[140]
# Generator_loss:2.3527
# L1_loss:0.1671
# Discriminator_loss:0.7216
#
# EPOCH[9] - STEP[150]
# Generator_loss:1.5723
# L1_loss:0.1321
# Discriminator_loss:0.7237
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.4432
# L1_loss:0.1623
# Discriminator_loss:1.1937
#
# EPOCH[9] - STEP[170]
# Generator_loss:1.6989
# L1_loss:0.1784
# Discriminator_loss:0.9260
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.2652
# L1_loss:0.1938
# Discriminator_loss:0.4890
#
# EPOCH[9] - STEP[190]
# Generator_loss:1.4079
# L1_loss:0.1686
# Discriminator_loss:0.5879
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.4744
# L1_loss:0.1523
# Discriminator_loss:0.9039
#
# EPOCH[9] - STEP[210]
# Generator_loss:1.3659
# L1_loss:0.1901
# Discriminator_loss:0.8636
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.0758
# L1_loss:0.1792
# Discriminator_loss:2.1038
#
# EPOCH[9] - STEP[230]
# Generator_loss:1.5996
# L1_loss:0.1845
# Discriminator_loss:0.3497
#
# EPOCH[9] - STEP[240]
# Generator_loss:2.4753
# L1_loss:0.1893
# Discriminator_loss:2.0365
#
# EPOCH[9] - STEP[250]
# Generator_loss:1.9226
# L1_loss:0.1669
# Discriminator_loss:1.3662
#
# EPOCH[10] - STEP[10]
# Generator_loss:0.5513
# L1_loss:0.1916
# Discriminator_loss:1.1009
#
# EPOCH[10] - STEP[20]
# Generator_loss:0.9761
# L1_loss:0.1659
# Discriminator_loss:1.8972
#
# EPOCH[10] - STEP[30]
# Generator_loss:0.8182
# L1_loss:0.1911
# Discriminator_loss:0.7799
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.2302
# L1_loss:0.1759
# Discriminator_loss:0.9284
#
# EPOCH[10] - STEP[50]
# Generator_loss:0.4799
# L1_loss:0.1750
# Discriminator_loss:1.1460
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.0349
# L1_loss:0.2307
# Discriminator_loss:0.7288
#
# EPOCH[10] - STEP[70]
# Generator_loss:0.7335
# L1_loss:0.2068
# Discriminator_loss:1.0257
#
# EPOCH[10] - STEP[80]
# Generator_loss:1.3407
# L1_loss:0.1818
# Discriminator_loss:0.6243
#
# EPOCH[10] - STEP[90]
# Generator_loss:2.7440
# L1_loss:0.1825
# Discriminator_loss:1.0281
#
# EPOCH[10] - STEP[100]
# Generator_loss:1.2063
# L1_loss:0.1803
# Discriminator_loss:1.2288
#
# EPOCH[10] - STEP[110]
# Generator_loss:2.1307
# L1_loss:0.1963
# Discriminator_loss:0.8682
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.2929
# L1_loss:0.1845
# Discriminator_loss:0.6654
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.4969
# L1_loss:0.1535
# Discriminator_loss:0.4849
#
# EPOCH[10] - STEP[140]
# Generator_loss:2.1979
# L1_loss:0.1964
# Discriminator_loss:0.4830
#
# EPOCH[10] - STEP[150]
# Generator_loss:0.6850
# L1_loss:0.1900
# Discriminator_loss:0.8529
#
# EPOCH[10] - STEP[160]
# Generator_loss:0.8062
# L1_loss:0.1765
# Discriminator_loss:0.7793
#
# EPOCH[10] - STEP[170]
# Generator_loss:1.0474
# L1_loss:0.1594
# Discriminator_loss:2.2055
#
# EPOCH[10] - STEP[180]
# Generator_loss:1.8300
# L1_loss:0.1923
# Discriminator_loss:0.3858
#
# EPOCH[10] - STEP[190]
# Generator_loss:0.4526
# L1_loss:0.1849
# Discriminator_loss:1.3764
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.0817
# L1_loss:0.1690
# Discriminator_loss:1.7034
#
# EPOCH[10] - STEP[210]
# Generator_loss:1.4359
# L1_loss:0.2054
# Discriminator_loss:1.0604
#
# EPOCH[10] - STEP[220]
# Generator_loss:2.0697
# L1_loss:0.1913
# Discriminator_loss:0.8734
#
# EPOCH[10] - STEP[230]
# Generator_loss:1.3200
# L1_loss:0.1804
# Discriminator_loss:0.9714
#
# EPOCH[10] - STEP[240]
# Generator_loss:0.6340
# L1_loss:0.1708
# Discriminator_loss:0.9625
#
# EPOCH[10] - STEP[250]
# Generator_loss:1.2744
# L1_loss:0.1975
# Discriminator_loss:0.7498

# %%
val_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/val/'
print("number of validation examples :", len(os.listdir(val_path)))
# Out:
# number of validation examples : 5

# %%
# 학습 결과 테스트
test_ind = 0

f = val_path + os.listdir(val_path)[test_ind]
colored, sketch = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# - 성능이 안좋아서 EPOCHS를 200으로 늘림

# %%
# 추가 200 epochs train
EPOCHS = 200

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 50회 반복마다 손실을 출력
        if (i+1) % 50 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[50]
# Generator_loss:1.1228
# L1_loss:0.1830
# Discriminator_loss:1.1033
#
# EPOCH[1] - STEP[100]
# Generator_loss:2.8448
# L1_loss:0.1779
# Discriminator_loss:0.9051
#
# EPOCH[1] - STEP[150]
# Generator_loss:2.3467
# L1_loss:0.1745
# Discriminator_loss:1.3287
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.2907
# L1_loss:0.1647
# Discriminator_loss:0.8349
#
# EPOCH[1] - STEP[250]
# Generator_loss:1.1153
# L1_loss:0.1904
# Discriminator_loss:0.6923
#
# EPOCH[2] - STEP[50]
# Generator_loss:1.7206
# L1_loss:0.1820
# Discriminator_loss:0.4457
#
# EPOCH[2] - STEP[100]
# Generator_loss:2.1673
# L1_loss:0.1901
# Discriminator_loss:0.5287
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.4035
# L1_loss:0.1936
# Discriminator_loss:0.6953
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.5739
# L1_loss:0.1561
# Discriminator_loss:1.3393
#
# EPOCH[2] - STEP[250]
# Generator_loss:0.5028
# L1_loss:0.2126
# Discriminator_loss:1.2404
#
# EPOCH[3] - STEP[50]
# Generator_loss:2.2087
# L1_loss:0.1819
# Discriminator_loss:0.9489
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.5187
# L1_loss:0.1563
# Discriminator_loss:0.4693
#
# EPOCH[3] - STEP[150]
# Generator_loss:1.9488
# L1_loss:0.1760
# Discriminator_loss:0.7982
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.1670
# L1_loss:0.1411
# Discriminator_loss:1.4045
#
# EPOCH[3] - STEP[250]
# Generator_loss:0.9859
# L1_loss:0.1602
# Discriminator_loss:0.7048
#
# EPOCH[4] - STEP[50]
# Generator_loss:0.6514
# L1_loss:0.1866
# Discriminator_loss:1.1103
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.5892
# L1_loss:0.1579
# Discriminator_loss:1.2229
#
# EPOCH[4] - STEP[150]
# Generator_loss:1.4127
# L1_loss:0.2069
# Discriminator_loss:0.4299
#
# EPOCH[4] - STEP[200]
# Generator_loss:0.6419
# L1_loss:0.1937
# Discriminator_loss:1.3869
#
# EPOCH[4] - STEP[250]
# Generator_loss:1.6113
# L1_loss:0.2386
# Discriminator_loss:0.3360
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.0252
# L1_loss:0.2338
# Discriminator_loss:0.8727
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.5583
# L1_loss:0.1979
# Discriminator_loss:0.2421
#
# EPOCH[5] - STEP[150]
# Generator_loss:0.9774
# L1_loss:0.1493
# Discriminator_loss:1.5203
#
# EPOCH[5] - STEP[200]
# Generator_loss:0.3245
# L1_loss:0.1943
# Discriminator_loss:1.4416
#
# EPOCH[5] - STEP[250]
# Generator_loss:1.4637
# L1_loss:0.1854
# Discriminator_loss:1.5851
#
# EPOCH[6] - STEP[50]
# Generator_loss:2.1866
# L1_loss:0.1670
# Discriminator_loss:1.5420
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.1047
# L1_loss:0.1824
# Discriminator_loss:0.7337
#
# EPOCH[6] - STEP[150]
# Generator_loss:2.1967
# L1_loss:0.1997
# Discriminator_loss:0.2919
#
# EPOCH[6] - STEP[200]
# Generator_loss:3.1390
# L1_loss:0.2095
# Discriminator_loss:0.2108
#
# EPOCH[6] - STEP[250]
# Generator_loss:1.6045
# L1_loss:0.1799
# Discriminator_loss:0.5111
#
# EPOCH[7] - STEP[50]
# Generator_loss:1.4836
# L1_loss:0.1838
# Discriminator_loss:0.8799
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.5161
# L1_loss:0.1822
# Discriminator_loss:0.4230
#
# EPOCH[7] - STEP[150]
# Generator_loss:1.5700
# L1_loss:0.1845
# Discriminator_loss:0.6025
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.0140
# L1_loss:0.1979
# Discriminator_loss:0.6230
#
# EPOCH[7] - STEP[250]
# Generator_loss:2.2189
# L1_loss:0.1730
# Discriminator_loss:1.1225
#
# EPOCH[8] - STEP[50]
# Generator_loss:2.3750
# L1_loss:0.1600
# Discriminator_loss:2.7437
#
# EPOCH[8] - STEP[100]
# Generator_loss:2.3249
# L1_loss:0.1720
# Discriminator_loss:0.5439
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.4628
# L1_loss:0.1816
# Discriminator_loss:0.6723
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.4584
# L1_loss:0.1613
# Discriminator_loss:0.4357
#
# EPOCH[8] - STEP[250]
# Generator_loss:2.0851
# L1_loss:0.1731
# Discriminator_loss:0.5323
#
# EPOCH[9] - STEP[50]
# Generator_loss:1.4015
# L1_loss:0.1542
# Discriminator_loss:1.3060
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.1022
# L1_loss:0.1618
# Discriminator_loss:0.7623
#
# EPOCH[9] - STEP[150]
# Generator_loss:1.8821
# L1_loss:0.1743
# Discriminator_loss:1.1133
#
# EPOCH[9] - STEP[200]
# Generator_loss:0.4376
# L1_loss:0.1738
# Discriminator_loss:2.3503
#
# EPOCH[9] - STEP[250]
# Generator_loss:0.4259
# L1_loss:0.1643
# Discriminator_loss:1.3040
#
# EPOCH[10] - STEP[50]
# Generator_loss:2.4127
# L1_loss:0.1960
# Discriminator_loss:0.4265
#
# EPOCH[10] - STEP[100]
# Generator_loss:0.4190
# L1_loss:0.1835
# Discriminator_loss:1.5666
#
# EPOCH[10] - STEP[150]
# Generator_loss:1.7881
# L1_loss:0.1635
# Discriminator_loss:1.7494
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.3625
# L1_loss:0.2351
# Discriminator_loss:0.4904
#
# EPOCH[10] - STEP[250]
# Generator_loss:1.4541
# L1_loss:0.1989
# Discriminator_loss:0.6752
#
# EPOCH[11] - STEP[50]
# Generator_loss:1.5308
# L1_loss:0.1779
# Discriminator_loss:0.4631
#
# EPOCH[11] - STEP[100]
# Generator_loss:1.7843
# L1_loss:0.1380
# Discriminator_loss:1.9795
#
# EPOCH[11] - STEP[150]
# Generator_loss:1.2046
# L1_loss:0.1555
# Discriminator_loss:0.8201
#
# EPOCH[11] - STEP[200]
# Generator_loss:1.2298
# L1_loss:0.1792
# Discriminator_loss:0.6410
#
# EPOCH[11] - STEP[250]
# Generator_loss:0.6368
# L1_loss:0.1615
# Discriminator_loss:1.2960
#
# EPOCH[12] - STEP[50]
# Generator_loss:2.2698
# L1_loss:0.1983
# Discriminator_loss:0.7615
#
# EPOCH[12] - STEP[100]
# Generator_loss:0.6609
# L1_loss:0.1923
# Discriminator_loss:0.9160
#
# EPOCH[12] - STEP[150]
# Generator_loss:1.4030
# L1_loss:0.1752
# Discriminator_loss:1.2191
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.1744
# L1_loss:0.2360
# Discriminator_loss:0.4461
#
# EPOCH[12] - STEP[250]
# Generator_loss:1.5736
# L1_loss:0.2158
# Discriminator_loss:0.2917
#
# EPOCH[13] - STEP[50]
# Generator_loss:2.0181
# L1_loss:0.1801
# Discriminator_loss:0.5632
#
# EPOCH[13] - STEP[100]
# Generator_loss:1.4722
# L1_loss:0.1543
# Discriminator_loss:0.9268
#
# EPOCH[13] - STEP[150]
# Generator_loss:0.8083
# L1_loss:0.1733
# Discriminator_loss:2.0489
#
# EPOCH[13] - STEP[200]
# Generator_loss:0.9964
# L1_loss:0.1829
# Discriminator_loss:3.1667
#
# EPOCH[13] - STEP[250]
# Generator_loss:0.5868
# L1_loss:0.1871
# Discriminator_loss:1.1720
#
# EPOCH[14] - STEP[50]
# Generator_loss:1.0378
# L1_loss:0.1832
# Discriminator_loss:0.6093
#
# EPOCH[14] - STEP[100]
# Generator_loss:1.5226
# L1_loss:0.1653
# Discriminator_loss:0.7596
#
# EPOCH[14] - STEP[150]
# Generator_loss:0.9407
# L1_loss:0.1553
# Discriminator_loss:2.6725
#
# EPOCH[14] - STEP[200]
# Generator_loss:2.2050
# L1_loss:0.1747
# Discriminator_loss:1.0410
#
# EPOCH[14] - STEP[250]
# Generator_loss:1.0988
# L1_loss:0.1778
# Discriminator_loss:0.6457
#
# EPOCH[15] - STEP[50]
# Generator_loss:1.2868
# L1_loss:0.1851
# Discriminator_loss:0.6224
#
# EPOCH[15] - STEP[100]
# Generator_loss:0.4914
# L1_loss:0.1710
# Discriminator_loss:1.3372
#
# EPOCH[15] - STEP[150]
# Generator_loss:0.7423
# L1_loss:0.2113
# Discriminator_loss:1.0142
#
# EPOCH[15] - STEP[200]
# Generator_loss:2.0124
# L1_loss:0.1887
# Discriminator_loss:0.3063
#
# EPOCH[15] - STEP[250]
# Generator_loss:0.7569
# L1_loss:0.2046
# Discriminator_loss:0.8655
#
# EPOCH[16] - STEP[50]
# Generator_loss:1.3181
# L1_loss:0.1867
# Discriminator_loss:1.1418
#
# EPOCH[16] - STEP[100]
# Generator_loss:2.2024
# L1_loss:0.1562
# Discriminator_loss:1.5522
#
# EPOCH[16] - STEP[150]
# Generator_loss:0.6982
# L1_loss:0.1722
# Discriminator_loss:0.8474
#
# EPOCH[16] - STEP[200]
# Generator_loss:1.1906
# L1_loss:0.1721
# Discriminator_loss:0.6145
#
# EPOCH[16] - STEP[250]
# Generator_loss:0.7573
# L1_loss:0.1707
# Discriminator_loss:1.0247
#
# EPOCH[17] - STEP[50]
# Generator_loss:1.5197
# L1_loss:0.1595
# Discriminator_loss:2.6082
#
# EPOCH[17] - STEP[100]
# Generator_loss:1.1879
# L1_loss:0.1912
# Discriminator_loss:0.6148
#
# EPOCH[17] - STEP[150]
# Generator_loss:1.1255
# L1_loss:0.1648
# Discriminator_loss:1.5826
#
# EPOCH[17] - STEP[200]
# Generator_loss:0.6707
# L1_loss:0.1860
# Discriminator_loss:0.8667
#
# EPOCH[17] - STEP[250]
# Generator_loss:0.7529
# L1_loss:0.1592
# Discriminator_loss:0.7976
#
# EPOCH[18] - STEP[50]
# Generator_loss:1.8080
# L1_loss:0.1806
# Discriminator_loss:0.2429
#
# EPOCH[18] - STEP[100]
# Generator_loss:1.4183
# L1_loss:0.1644
# Discriminator_loss:0.8241
#
# EPOCH[18] - STEP[150]
# Generator_loss:1.2005
# L1_loss:0.1827
# Discriminator_loss:0.7599
#
# EPOCH[18] - STEP[200]
# Generator_loss:0.2846
# L1_loss:0.1484
# Discriminator_loss:1.6136
#
# EPOCH[18] - STEP[250]
# Generator_loss:1.3433
# L1_loss:0.1576
# Discriminator_loss:0.5992
#
# EPOCH[19] - STEP[50]
# Generator_loss:0.4532
# L1_loss:0.1956
# Discriminator_loss:1.2079
#
# EPOCH[19] - STEP[100]
# Generator_loss:0.9711
# L1_loss:0.2128
# Discriminator_loss:0.6267
#
# EPOCH[19] - STEP[150]
# Generator_loss:1.1845
# L1_loss:0.1681
# Discriminator_loss:1.0328
#
# EPOCH[19] - STEP[200]
# Generator_loss:0.2738
# L1_loss:0.1609
# Discriminator_loss:1.6515
#
# EPOCH[19] - STEP[250]
# Generator_loss:0.9998
# L1_loss:0.1813
# Discriminator_loss:1.2420
#
# EPOCH[20] - STEP[50]
# Generator_loss:0.6790
# L1_loss:0.1935
# Discriminator_loss:0.9278
#
# EPOCH[20] - STEP[100]
# Generator_loss:2.1079
# L1_loss:0.1720
# Discriminator_loss:0.7165
#
# EPOCH[20] - STEP[150]
# Generator_loss:0.8119
# L1_loss:0.2472
# Discriminator_loss:0.6887
#
# EPOCH[20] - STEP[200]
# Generator_loss:1.2250
# L1_loss:0.1585
# Discriminator_loss:1.4101
#
# EPOCH[20] - STEP[250]
# Generator_loss:1.0424
# L1_loss:0.1658
# Discriminator_loss:2.6822
#
# EPOCH[21] - STEP[50]
# Generator_loss:2.2393
# L1_loss:0.2318
# Discriminator_loss:0.1751
#
# EPOCH[21] - STEP[100]
# Generator_loss:1.7058
# L1_loss:0.1822
# Discriminator_loss:0.8580
#
# EPOCH[21] - STEP[150]
# Generator_loss:1.2148
# L1_loss:0.1752
# Discriminator_loss:0.5665
#
# EPOCH[21] - STEP[200]
# Generator_loss:2.2402
# L1_loss:0.1564
# Discriminator_loss:2.3954
#
# EPOCH[21] - STEP[250]
# Generator_loss:0.4956
# L1_loss:0.1567
# Discriminator_loss:1.4713
#
# EPOCH[22] - STEP[50]
# Generator_loss:2.1896
# L1_loss:0.2030
# Discriminator_loss:0.1709
#
# EPOCH[22] - STEP[100]
# Generator_loss:0.6951
# L1_loss:0.1862
# Discriminator_loss:1.2672
#
# EPOCH[22] - STEP[150]
# Generator_loss:1.7888
# L1_loss:0.1795
# Discriminator_loss:1.4327
#
# EPOCH[22] - STEP[200]
# Generator_loss:1.8627
# L1_loss:0.1778
# Discriminator_loss:0.8707
#
# EPOCH[22] - STEP[250]
# Generator_loss:2.4101
# L1_loss:0.1857
# Discriminator_loss:0.6662
#
# EPOCH[23] - STEP[50]
# Generator_loss:0.9847
# L1_loss:0.1922
# Discriminator_loss:0.6221
#
# EPOCH[23] - STEP[100]
# Generator_loss:0.5390
# L1_loss:0.2501
# Discriminator_loss:1.0657
#
# EPOCH[23] - STEP[150]
# Generator_loss:1.1691
# L1_loss:0.1764
# Discriminator_loss:0.6456
#
# EPOCH[23] - STEP[200]
# Generator_loss:1.2963
# L1_loss:0.2272
# Discriminator_loss:0.5065
#
# EPOCH[23] - STEP[250]
# Generator_loss:1.8271
# L1_loss:0.1778
# Discriminator_loss:0.7293
#
# EPOCH[24] - STEP[50]
# Generator_loss:1.3874
# L1_loss:0.1842
# Discriminator_loss:0.4551
#
# EPOCH[24] - STEP[100]
# Generator_loss:0.6552
# L1_loss:0.1888
# Discriminator_loss:0.8541
#
# EPOCH[24] - STEP[150]
# Generator_loss:1.7943
# L1_loss:0.1933
# Discriminator_loss:0.2628
#
# EPOCH[24] - STEP[200]
# Generator_loss:2.0871
# L1_loss:0.1924
# Discriminator_loss:0.5626
#
# EPOCH[24] - STEP[250]
# Generator_loss:1.5725
# L1_loss:0.1539
# Discriminator_loss:1.3185
#
# EPOCH[25] - STEP[50]
# Generator_loss:2.0770
# L1_loss:0.1824
# Discriminator_loss:2.0267
#
# EPOCH[25] - STEP[100]
# Generator_loss:1.9528
# L1_loss:0.1535
# Discriminator_loss:0.5128
#
# EPOCH[25] - STEP[150]
# Generator_loss:0.3797
# L1_loss:0.1568
# Discriminator_loss:2.2274
#
# EPOCH[25] - STEP[200]
# Generator_loss:0.2839
# L1_loss:0.1750
# Discriminator_loss:2.8371
#
# EPOCH[25] - STEP[250]
# Generator_loss:0.6396
# L1_loss:0.1920
# Discriminator_loss:0.9946
#
# EPOCH[26] - STEP[50]
# Generator_loss:0.2476
# L1_loss:0.2000
# Discriminator_loss:1.7372
#
# EPOCH[26] - STEP[100]
# Generator_loss:1.6035
# L1_loss:0.2152
# Discriminator_loss:0.9439
#
# EPOCH[26] - STEP[150]
# Generator_loss:1.0892
# L1_loss:0.1624
# Discriminator_loss:0.8641
#
# EPOCH[26] - STEP[200]
# Generator_loss:1.6544
# L1_loss:0.1628
# Discriminator_loss:1.3375
#
# EPOCH[26] - STEP[250]
# Generator_loss:1.0575
# L1_loss:0.1419
# Discriminator_loss:1.0090
#
# EPOCH[27] - STEP[50]
# Generator_loss:2.1442
# L1_loss:0.1686
# Discriminator_loss:1.5908
#
# EPOCH[27] - STEP[100]
# Generator_loss:1.1010
# L1_loss:0.1629
# Discriminator_loss:0.9672
#
# EPOCH[27] - STEP[150]
# Generator_loss:1.6446
# L1_loss:0.1641
# Discriminator_loss:0.8852
#
# EPOCH[27] - STEP[200]
# Generator_loss:1.1769
# L1_loss:0.1690
# Discriminator_loss:0.9338
#
# EPOCH[27] - STEP[250]
# Generator_loss:0.5248
# L1_loss:0.1652
# Discriminator_loss:1.5786
#
# EPOCH[28] - STEP[50]
# Generator_loss:1.6750
# L1_loss:0.1540
# Discriminator_loss:2.5186
#
# EPOCH[28] - STEP[100]
# Generator_loss:0.9714
# L1_loss:0.1705
# Discriminator_loss:0.8576
#
# EPOCH[28] - STEP[150]
# Generator_loss:1.4938
# L1_loss:0.1655
# Discriminator_loss:0.3991
#
# EPOCH[28] - STEP[200]
# Generator_loss:1.5730
# L1_loss:0.1964
# Discriminator_loss:0.4292
#
# EPOCH[28] - STEP[250]
# Generator_loss:0.5519
# L1_loss:0.1772
# Discriminator_loss:1.7475
#
# EPOCH[29] - STEP[50]
# Generator_loss:1.1650
# L1_loss:0.1701
# Discriminator_loss:0.7590
#
# EPOCH[29] - STEP[100]
# Generator_loss:2.0982
# L1_loss:0.1809
# Discriminator_loss:0.6486
#
# EPOCH[29] - STEP[150]
# Generator_loss:1.6664
# L1_loss:0.1700
# Discriminator_loss:1.0860
#
# EPOCH[29] - STEP[200]
# Generator_loss:1.5252
# L1_loss:0.1645
# Discriminator_loss:0.5171
#
# EPOCH[29] - STEP[250]
# Generator_loss:1.2206
# L1_loss:0.1614
# Discriminator_loss:0.6039
#
# EPOCH[30] - STEP[50]
# Generator_loss:1.1058
# L1_loss:0.1628
# Discriminator_loss:0.5799
#
# EPOCH[30] - STEP[100]
# Generator_loss:1.0300
# L1_loss:0.1964
# Discriminator_loss:0.5747
#
# EPOCH[30] - STEP[150]
# Generator_loss:0.9065
# L1_loss:0.1641
# Discriminator_loss:1.5363
#
# EPOCH[30] - STEP[200]
# Generator_loss:1.5442
# L1_loss:0.1517
# Discriminator_loss:1.0465
#
# EPOCH[30] - STEP[250]
# Generator_loss:1.3738
# L1_loss:0.1580
# Discriminator_loss:0.4415
#
# EPOCH[31] - STEP[50]
# Generator_loss:0.3899
# L1_loss:0.2291
# Discriminator_loss:1.3368
#
# EPOCH[31] - STEP[100]
# Generator_loss:0.5662
# L1_loss:0.1847
# Discriminator_loss:1.1418
#
# EPOCH[31] - STEP[150]
# Generator_loss:1.6612
# L1_loss:0.1636
# Discriminator_loss:1.2691
#
# EPOCH[31] - STEP[200]
# Generator_loss:0.6745
# L1_loss:0.1918
# Discriminator_loss:0.8224
#
# EPOCH[31] - STEP[250]
# Generator_loss:1.1509
# L1_loss:0.1939
# Discriminator_loss:0.7456
#
# EPOCH[32] - STEP[50]
# Generator_loss:2.3130
# L1_loss:0.1849
# Discriminator_loss:0.1760
#
# EPOCH[32] - STEP[100]
# Generator_loss:0.7519
# L1_loss:0.2007
# Discriminator_loss:0.9941
#
# EPOCH[32] - STEP[150]
# Generator_loss:0.6279
# L1_loss:0.1575
# Discriminator_loss:1.2919
#
# EPOCH[32] - STEP[200]
# Generator_loss:0.9230
# L1_loss:0.2020
# Discriminator_loss:0.9485
#
# EPOCH[32] - STEP[250]
# Generator_loss:3.4980
# L1_loss:0.1666
# Discriminator_loss:1.9562
#
# EPOCH[33] - STEP[50]
# Generator_loss:1.7580
# L1_loss:0.1674
# Discriminator_loss:1.3682
#
# EPOCH[33] - STEP[100]
# Generator_loss:2.0636
# L1_loss:0.1994
# Discriminator_loss:0.5115
#
# EPOCH[33] - STEP[150]
# Generator_loss:0.5930
# L1_loss:0.1597
# Discriminator_loss:1.9683
#
# EPOCH[33] - STEP[200]
# Generator_loss:1.2754
# L1_loss:0.1690
# Discriminator_loss:0.6126
#
# EPOCH[33] - STEP[250]
# Generator_loss:2.7165
# L1_loss:0.1626
# Discriminator_loss:2.7272
#
# EPOCH[34] - STEP[50]
# Generator_loss:1.4608
# L1_loss:0.1640
# Discriminator_loss:1.4757
#
# EPOCH[34] - STEP[100]
# Generator_loss:0.5144
# L1_loss:0.1813
# Discriminator_loss:1.1532
#
# EPOCH[34] - STEP[150]
# Generator_loss:0.5756
# L1_loss:0.1777
# Discriminator_loss:1.2374
#
# EPOCH[34] - STEP[200]
# Generator_loss:1.7369
# L1_loss:0.1847
# Discriminator_loss:0.9050
#
# EPOCH[34] - STEP[250]
# Generator_loss:1.9545
# L1_loss:0.1777
# Discriminator_loss:0.6062
#
# EPOCH[35] - STEP[50]
# Generator_loss:0.9815
# L1_loss:0.1847
# Discriminator_loss:0.7338
#
# EPOCH[35] - STEP[100]
# Generator_loss:1.1355
# L1_loss:0.1941
# Discriminator_loss:1.0382
#
# EPOCH[35] - STEP[150]
# Generator_loss:1.8467
# L1_loss:0.1764
# Discriminator_loss:0.3332
#
# EPOCH[35] - STEP[200]
# Generator_loss:0.5644
# L1_loss:0.1494
# Discriminator_loss:2.2078
#
# EPOCH[35] - STEP[250]
# Generator_loss:1.7980
# L1_loss:0.1563
# Discriminator_loss:0.7777
#
# EPOCH[36] - STEP[50]
# Generator_loss:1.9730
# L1_loss:0.1818
# Discriminator_loss:1.1702
#
# EPOCH[36] - STEP[100]
# Generator_loss:1.0862
# L1_loss:0.1679
# Discriminator_loss:0.8066
#
# EPOCH[36] - STEP[150]
# Generator_loss:0.6974
# L1_loss:0.2084
# Discriminator_loss:1.1604
#
# EPOCH[36] - STEP[200]
# Generator_loss:1.7919
# L1_loss:0.1802
# Discriminator_loss:0.9454
#
# EPOCH[36] - STEP[250]
# Generator_loss:2.9482
# L1_loss:0.1810
# Discriminator_loss:0.3021
#
# EPOCH[37] - STEP[50]
# Generator_loss:1.7951
# L1_loss:0.1784
# Discriminator_loss:1.0410
#
# EPOCH[37] - STEP[100]
# Generator_loss:0.2718
# L1_loss:0.1806
# Discriminator_loss:1.5950
#
# EPOCH[37] - STEP[150]
# Generator_loss:1.4937
# L1_loss:0.1714
# Discriminator_loss:1.0052
#
# EPOCH[37] - STEP[200]
# Generator_loss:0.7907
# L1_loss:0.1824
# Discriminator_loss:0.8180
#
# EPOCH[37] - STEP[250]
# Generator_loss:2.0490
# L1_loss:0.1584
# Discriminator_loss:0.6556
#
# EPOCH[38] - STEP[50]
# Generator_loss:2.2403
# L1_loss:0.1575
# Discriminator_loss:0.5617
#
# EPOCH[38] - STEP[100]
# Generator_loss:0.5647
# L1_loss:0.1601
# Discriminator_loss:2.0906
#
# EPOCH[38] - STEP[150]
# Generator_loss:1.7530
# L1_loss:0.1783
# Discriminator_loss:0.5368
#
# EPOCH[38] - STEP[200]
# Generator_loss:1.1602
# L1_loss:0.1759
# Discriminator_loss:0.8362
#
# EPOCH[38] - STEP[250]
# Generator_loss:1.7372
# L1_loss:0.1647
# Discriminator_loss:0.5592
#
# EPOCH[39] - STEP[50]
# Generator_loss:1.2436
# L1_loss:0.1726
# Discriminator_loss:0.5366
#
# EPOCH[39] - STEP[100]
# Generator_loss:2.4574
# L1_loss:0.1696
# Discriminator_loss:1.1680
#
# EPOCH[39] - STEP[150]
# Generator_loss:1.3694
# L1_loss:0.1800
# Discriminator_loss:0.4474
#
# EPOCH[39] - STEP[200]
# Generator_loss:1.9738
# L1_loss:0.1646
# Discriminator_loss:0.5405
#
# EPOCH[39] - STEP[250]
# Generator_loss:0.3411
# L1_loss:0.1844
# Discriminator_loss:1.3729
#
# EPOCH[40] - STEP[50]
# Generator_loss:1.3732
# L1_loss:0.1536
# Discriminator_loss:1.7076
#
# EPOCH[40] - STEP[100]
# Generator_loss:1.3634
# L1_loss:0.1813
# Discriminator_loss:0.8274
#
# EPOCH[40] - STEP[150]
# Generator_loss:0.8509
# L1_loss:0.1840
# Discriminator_loss:0.7072
#
# EPOCH[40] - STEP[200]
# Generator_loss:1.0805
# L1_loss:0.1455
# Discriminator_loss:2.1514
#
# EPOCH[40] - STEP[250]
# Generator_loss:2.3996
# L1_loss:0.1992
# Discriminator_loss:0.2428
#
# EPOCH[41] - STEP[50]
# Generator_loss:1.3649
# L1_loss:0.1757
# Discriminator_loss:1.1945
#
# EPOCH[41] - STEP[100]
# Generator_loss:1.0828
# L1_loss:0.1666
# Discriminator_loss:1.2350
#
# EPOCH[41] - STEP[150]
# Generator_loss:1.9307
# L1_loss:0.1741
# Discriminator_loss:0.5301
#
# EPOCH[41] - STEP[200]
# Generator_loss:2.1025
# L1_loss:0.1462
# Discriminator_loss:1.9717
#
# EPOCH[41] - STEP[250]
# Generator_loss:1.9031
# L1_loss:0.1665
# Discriminator_loss:1.5445
#
# EPOCH[42] - STEP[50]
# Generator_loss:1.7474
# L1_loss:0.1912
# Discriminator_loss:1.9803
#
# EPOCH[42] - STEP[100]
# Generator_loss:2.1107
# L1_loss:0.1666
# Discriminator_loss:0.2427
#
# EPOCH[42] - STEP[150]
# Generator_loss:1.3144
# L1_loss:0.1574
# Discriminator_loss:0.6279
#
# EPOCH[42] - STEP[200]
# Generator_loss:2.3850
# L1_loss:0.1706
# Discriminator_loss:0.5282
#
# EPOCH[42] - STEP[250]
# Generator_loss:2.3143
# L1_loss:0.1981
# Discriminator_loss:0.5787
#
# EPOCH[43] - STEP[50]
# Generator_loss:1.2711
# L1_loss:0.1899
# Discriminator_loss:0.4968
#
# EPOCH[43] - STEP[100]
# Generator_loss:1.0398
# L1_loss:0.1858
# Discriminator_loss:0.9498
#
# EPOCH[43] - STEP[150]
# Generator_loss:1.4302
# L1_loss:0.1567
# Discriminator_loss:0.7889
#
# EPOCH[43] - STEP[200]
# Generator_loss:1.8544
# L1_loss:0.1966
# Discriminator_loss:1.5579
#
# EPOCH[43] - STEP[250]
# Generator_loss:2.3432
# L1_loss:0.1625
# Discriminator_loss:1.2248
#
# EPOCH[44] - STEP[50]
# Generator_loss:2.4264
# L1_loss:0.1682
# Discriminator_loss:0.7378
#
# EPOCH[44] - STEP[100]
# Generator_loss:1.2398
# L1_loss:0.1835
# Discriminator_loss:0.6115
#
# EPOCH[44] - STEP[150]
# Generator_loss:1.3831
# L1_loss:0.1579
# Discriminator_loss:0.9083
#
# EPOCH[44] - STEP[200]
# Generator_loss:1.7477
# L1_loss:0.1887
# Discriminator_loss:0.4163
#
# EPOCH[44] - STEP[250]
# Generator_loss:1.3139
# L1_loss:0.1994
# Discriminator_loss:0.7748
#
# EPOCH[45] - STEP[50]
# Generator_loss:0.5588
# L1_loss:0.2130
# Discriminator_loss:1.0121
#
# EPOCH[45] - STEP[100]
# Generator_loss:1.7127
# L1_loss:0.1798
# Discriminator_loss:0.6786
#
# EPOCH[45] - STEP[150]
# Generator_loss:1.8524
# L1_loss:0.1596
# Discriminator_loss:0.9893
#
# EPOCH[45] - STEP[200]
# Generator_loss:0.6989
# L1_loss:0.1720
# Discriminator_loss:0.9660
#
# EPOCH[45] - STEP[250]
# Generator_loss:0.3790
# L1_loss:0.1794
# Discriminator_loss:1.5825
#
# EPOCH[46] - STEP[50]
# Generator_loss:1.5338
# L1_loss:0.1843
# Discriminator_loss:0.3833
#
# EPOCH[46] - STEP[100]
# Generator_loss:1.1963
# L1_loss:0.1450
# Discriminator_loss:1.7789
#
# EPOCH[46] - STEP[150]
# Generator_loss:0.8687
# L1_loss:0.1597
# Discriminator_loss:1.1272
#
# EPOCH[46] - STEP[200]
# Generator_loss:2.1758
# L1_loss:0.2083
# Discriminator_loss:0.3086
#
# EPOCH[46] - STEP[250]
# Generator_loss:1.7460
# L1_loss:0.1587
# Discriminator_loss:1.0603
#
# EPOCH[47] - STEP[50]
# Generator_loss:0.6821
# L1_loss:0.1916
# Discriminator_loss:0.8643
#
# EPOCH[47] - STEP[100]
# Generator_loss:1.2627
# L1_loss:0.1927
# Discriminator_loss:0.9482
#
# EPOCH[47] - STEP[150]
# Generator_loss:2.0658
# L1_loss:0.1659
# Discriminator_loss:0.9391
#
# EPOCH[47] - STEP[200]
# Generator_loss:0.4934
# L1_loss:0.2114
# Discriminator_loss:1.1282
#
# EPOCH[47] - STEP[250]
# Generator_loss:1.8997
# L1_loss:0.1717
# Discriminator_loss:1.4742
#
# EPOCH[48] - STEP[50]
# Generator_loss:2.4067
# L1_loss:0.1526
# Discriminator_loss:1.0099
#
# EPOCH[48] - STEP[100]
# Generator_loss:0.9243
# L1_loss:0.1714
# Discriminator_loss:0.9207
#
# EPOCH[48] - STEP[150]
# Generator_loss:1.4496
# L1_loss:0.1642
# Discriminator_loss:0.6167
#
# EPOCH[48] - STEP[200]
# Generator_loss:0.9721
# L1_loss:0.1683
# Discriminator_loss:0.8937
#
# EPOCH[48] - STEP[250]
# Generator_loss:1.9808
# L1_loss:0.1487
# Discriminator_loss:1.1091
#
# EPOCH[49] - STEP[50]
# Generator_loss:0.4492
# L1_loss:0.1743
# Discriminator_loss:1.2492
#
# EPOCH[49] - STEP[100]
# Generator_loss:1.2687
# L1_loss:0.1759
# Discriminator_loss:0.6599
#
# EPOCH[49] - STEP[150]
# Generator_loss:2.7100
# L1_loss:0.1633
# Discriminator_loss:0.4194
#
# EPOCH[49] - STEP[200]
# Generator_loss:0.8477
# L1_loss:0.1829
# Discriminator_loss:0.9254
#
# EPOCH[49] - STEP[250]
# Generator_loss:1.2011
# L1_loss:0.1885
# Discriminator_loss:1.1800
#
# EPOCH[50] - STEP[50]
# Generator_loss:1.1604
# L1_loss:0.1628
# Discriminator_loss:0.5062
#
# EPOCH[50] - STEP[100]
# Generator_loss:0.9002
# L1_loss:0.1808
# Discriminator_loss:0.6500
#
# EPOCH[50] - STEP[150]
# Generator_loss:1.8357
# L1_loss:0.2196
# Discriminator_loss:0.2262
#
# EPOCH[50] - STEP[200]
# Generator_loss:0.7640
# L1_loss:0.1800
# Discriminator_loss:0.7839
#
# EPOCH[50] - STEP[250]
# Generator_loss:1.1159
# L1_loss:0.1599
# Discriminator_loss:0.8361
#
# EPOCH[51] - STEP[50]
# Generator_loss:0.8429
# L1_loss:0.1765
# Discriminator_loss:0.7149
#
# EPOCH[51] - STEP[100]
# Generator_loss:1.5681
# L1_loss:0.1655
# Discriminator_loss:0.5836
#
# EPOCH[51] - STEP[150]
# Generator_loss:1.4548
# L1_loss:0.1994
# Discriminator_loss:0.3812
#
# EPOCH[51] - STEP[200]
# Generator_loss:0.6977
# L1_loss:0.1915
# Discriminator_loss:0.8520
#
# EPOCH[51] - STEP[250]
# Generator_loss:2.5556
# L1_loss:0.1981
# Discriminator_loss:0.2801
#
# EPOCH[52] - STEP[50]
# Generator_loss:1.3159
# L1_loss:0.1675
# Discriminator_loss:0.9922
#
# EPOCH[52] - STEP[100]
# Generator_loss:2.0704
# L1_loss:0.1670
# Discriminator_loss:1.1301
#
# EPOCH[52] - STEP[150]
# Generator_loss:1.0174
# L1_loss:0.1700
# Discriminator_loss:0.8459
#
# EPOCH[52] - STEP[200]
# Generator_loss:1.5758
# L1_loss:0.1569
# Discriminator_loss:1.7212
#
# EPOCH[52] - STEP[250]
# Generator_loss:1.2593
# L1_loss:0.1683
# Discriminator_loss:1.2797
#
# EPOCH[53] - STEP[50]
# Generator_loss:0.6316
# L1_loss:0.1715
# Discriminator_loss:1.6553
#
# EPOCH[53] - STEP[100]
# Generator_loss:1.5325
# L1_loss:0.1701
# Discriminator_loss:0.7073
#
# EPOCH[53] - STEP[150]
# Generator_loss:2.3365
# L1_loss:0.1956
# Discriminator_loss:0.1584
#
# EPOCH[53] - STEP[200]
# Generator_loss:1.9086
# L1_loss:0.1595
# Discriminator_loss:0.5766
#
# EPOCH[53] - STEP[250]
# Generator_loss:1.1891
# L1_loss:0.1742
# Discriminator_loss:0.5974
#
# EPOCH[54] - STEP[50]
# Generator_loss:0.7609
# L1_loss:0.1632
# Discriminator_loss:0.8899
#
# EPOCH[54] - STEP[100]
# Generator_loss:1.4597
# L1_loss:0.1677
# Discriminator_loss:0.7443
#
# EPOCH[54] - STEP[150]
# Generator_loss:0.5928
# L1_loss:0.1580
# Discriminator_loss:1.2547
#
# EPOCH[54] - STEP[200]
# Generator_loss:2.6163
# L1_loss:0.1459
# Discriminator_loss:1.7054
#
# EPOCH[54] - STEP[250]
# Generator_loss:0.7864
# L1_loss:0.1699
# Discriminator_loss:0.9121
#
# EPOCH[55] - STEP[50]
# Generator_loss:2.1214
# L1_loss:0.2098
# Discriminator_loss:0.1978
#
# EPOCH[55] - STEP[100]
# Generator_loss:1.9119
# L1_loss:0.1520
# Discriminator_loss:0.6126
#
# EPOCH[55] - STEP[150]
# Generator_loss:1.7033
# L1_loss:0.1730
# Discriminator_loss:0.3997
#
# EPOCH[55] - STEP[200]
# Generator_loss:1.3864
# L1_loss:0.2064
# Discriminator_loss:0.4324
#
# EPOCH[55] - STEP[250]
# Generator_loss:0.9871
# L1_loss:0.1703
# Discriminator_loss:0.9104
#
# EPOCH[56] - STEP[50]
# Generator_loss:1.9668
# L1_loss:0.1832
# Discriminator_loss:1.1798
#
# EPOCH[56] - STEP[100]
# Generator_loss:0.6842
# L1_loss:0.1675
# Discriminator_loss:1.3145
#
# EPOCH[56] - STEP[150]
# Generator_loss:0.5911
# L1_loss:0.2193
# Discriminator_loss:1.0134
#
# EPOCH[56] - STEP[200]
# Generator_loss:1.0377
# L1_loss:0.1513
# Discriminator_loss:1.1806
#
# EPOCH[56] - STEP[250]
# Generator_loss:1.6124
# L1_loss:0.1573
# Discriminator_loss:1.2650
#
# EPOCH[57] - STEP[50]
# Generator_loss:1.1705
# L1_loss:0.1657
# Discriminator_loss:0.4828
#
# EPOCH[57] - STEP[100]
# Generator_loss:1.8601
# L1_loss:0.1724
# Discriminator_loss:0.3511
#
# EPOCH[57] - STEP[150]
# Generator_loss:1.5597
# L1_loss:0.1652
# Discriminator_loss:0.4306
#
# EPOCH[57] - STEP[200]
# Generator_loss:0.7330
# L1_loss:0.1751
# Discriminator_loss:1.0587
#
# EPOCH[57] - STEP[250]
# Generator_loss:0.6445
# L1_loss:0.1583
# Discriminator_loss:2.7928
#
# EPOCH[58] - STEP[50]
# Generator_loss:1.2433
# L1_loss:0.1643
# Discriminator_loss:1.1094
#
# EPOCH[58] - STEP[100]
# Generator_loss:0.3120
# L1_loss:0.1864
# Discriminator_loss:1.4999
#
# EPOCH[58] - STEP[150]
# Generator_loss:2.7301
# L1_loss:0.1627
# Discriminator_loss:1.6915
#
# EPOCH[58] - STEP[200]
# Generator_loss:1.5433
# L1_loss:0.1735
# Discriminator_loss:0.6018
#
# EPOCH[58] - STEP[250]
# Generator_loss:1.3413
# L1_loss:0.1984
# Discriminator_loss:0.3917
#
# EPOCH[59] - STEP[50]
# Generator_loss:0.6252
# L1_loss:0.1768
# Discriminator_loss:1.1445
#
# EPOCH[59] - STEP[100]
# Generator_loss:0.6551
# L1_loss:0.1536
# Discriminator_loss:1.0657
#
# EPOCH[59] - STEP[150]
# Generator_loss:1.8418
# L1_loss:0.1992
# Discriminator_loss:0.2428
#
# EPOCH[59] - STEP[200]
# Generator_loss:0.4902
# L1_loss:0.1746
# Discriminator_loss:1.1412
#
# EPOCH[59] - STEP[250]
# Generator_loss:1.0443
# L1_loss:0.1936
# Discriminator_loss:0.8499
#
# EPOCH[60] - STEP[50]
# Generator_loss:0.8981
# L1_loss:0.1738
# Discriminator_loss:1.0275
#
# EPOCH[60] - STEP[100]
# Generator_loss:1.1583
# L1_loss:0.1646
# Discriminator_loss:0.7089
#
# EPOCH[60] - STEP[150]
# Generator_loss:0.9247
# L1_loss:0.1749
# Discriminator_loss:1.2065
#
# EPOCH[60] - STEP[200]
# Generator_loss:2.9602
# L1_loss:0.1984
# Discriminator_loss:0.1272
#
# EPOCH[60] - STEP[250]
# Generator_loss:1.4889
# L1_loss:0.1648
# Discriminator_loss:0.4106
#
# EPOCH[61] - STEP[50]
# Generator_loss:0.4012
# L1_loss:0.1754
# Discriminator_loss:1.8601
#
# EPOCH[61] - STEP[100]
# Generator_loss:1.3420
# L1_loss:0.1775
# Discriminator_loss:0.5381
#
# EPOCH[61] - STEP[150]
# Generator_loss:1.7926
# L1_loss:0.1726
# Discriminator_loss:0.4855
#
# EPOCH[61] - STEP[200]
# Generator_loss:0.6386
# L1_loss:0.1951
# Discriminator_loss:0.9463
#
# EPOCH[61] - STEP[250]
# Generator_loss:2.0387
# L1_loss:0.1623
# Discriminator_loss:0.4904
#
# EPOCH[62] - STEP[50]
# Generator_loss:0.5960
# L1_loss:0.1770
# Discriminator_loss:1.1989
#
# EPOCH[62] - STEP[100]
# Generator_loss:0.6929
# L1_loss:0.1580
# Discriminator_loss:1.5028
#
# EPOCH[62] - STEP[150]
# Generator_loss:0.5907
# L1_loss:0.1838
# Discriminator_loss:1.2118
#
# EPOCH[62] - STEP[200]
# Generator_loss:2.2934
# L1_loss:0.1773
# Discriminator_loss:0.5826
#
# EPOCH[62] - STEP[250]
# Generator_loss:0.7481
# L1_loss:0.1721
# Discriminator_loss:1.1603
#
# EPOCH[63] - STEP[50]
# Generator_loss:1.2999
# L1_loss:0.1705
# Discriminator_loss:0.8818
#
# EPOCH[63] - STEP[100]
# Generator_loss:1.7330
# L1_loss:0.1619
# Discriminator_loss:1.0744
#
# EPOCH[63] - STEP[150]
# Generator_loss:1.2419
# L1_loss:0.1734
# Discriminator_loss:0.6278
#
# EPOCH[63] - STEP[200]
# Generator_loss:2.0448
# L1_loss:0.1826
# Discriminator_loss:0.5956
#
# EPOCH[63] - STEP[250]
# Generator_loss:2.0889
# L1_loss:0.1602
# Discriminator_loss:0.5949
#
# EPOCH[64] - STEP[50]
# Generator_loss:2.7538
# L1_loss:0.1935
# Discriminator_loss:0.2080
#
# EPOCH[64] - STEP[100]
# Generator_loss:1.7669
# L1_loss:0.1443
# Discriminator_loss:1.6943
#
# EPOCH[64] - STEP[150]
# Generator_loss:1.3186
# L1_loss:0.2279
# Discriminator_loss:0.5156
#
# EPOCH[64] - STEP[200]
# Generator_loss:1.6378
# L1_loss:0.1883
# Discriminator_loss:0.7505
#
# EPOCH[64] - STEP[250]
# Generator_loss:1.6213
# L1_loss:0.1715
# Discriminator_loss:1.7593
#
# EPOCH[65] - STEP[50]
# Generator_loss:2.1239
# L1_loss:0.1689
# Discriminator_loss:0.4093
#
# EPOCH[65] - STEP[100]
# Generator_loss:0.9682
# L1_loss:0.1605
# Discriminator_loss:1.0572
#
# EPOCH[65] - STEP[150]
# Generator_loss:2.0260
# L1_loss:0.1729
# Discriminator_loss:0.7676
#
# EPOCH[65] - STEP[200]
# Generator_loss:1.3560
# L1_loss:0.1460
# Discriminator_loss:0.7650
#
# EPOCH[65] - STEP[250]
# Generator_loss:1.9661
# L1_loss:0.1958
# Discriminator_loss:0.4287
#
# EPOCH[66] - STEP[50]
# Generator_loss:2.2665
# L1_loss:0.1752
# Discriminator_loss:0.3403
#
# EPOCH[66] - STEP[100]
# Generator_loss:1.2557
# L1_loss:0.1467
# Discriminator_loss:0.8106
#
# EPOCH[66] - STEP[150]
# Generator_loss:1.5970
# L1_loss:0.1765
# Discriminator_loss:0.8221
#
# EPOCH[66] - STEP[200]
# Generator_loss:1.6539
# L1_loss:0.1841
# Discriminator_loss:0.3226
#
# EPOCH[66] - STEP[250]
# Generator_loss:2.3877
# L1_loss:0.1850
# Discriminator_loss:0.1918
#
# EPOCH[67] - STEP[50]
# Generator_loss:1.2942
# L1_loss:0.1647
# Discriminator_loss:1.1219
#
# EPOCH[67] - STEP[100]
# Generator_loss:2.3478
# L1_loss:0.1663
# Discriminator_loss:1.0731
#
# EPOCH[67] - STEP[150]
# Generator_loss:0.6728
# L1_loss:0.1836
# Discriminator_loss:1.3101
#
# EPOCH[67] - STEP[200]
# Generator_loss:1.1666
# L1_loss:0.1683
# Discriminator_loss:1.6232
#
# EPOCH[67] - STEP[250]
# Generator_loss:1.0838
# L1_loss:0.1994
# Discriminator_loss:0.6899
#
# EPOCH[68] - STEP[50]
# Generator_loss:0.6329
# L1_loss:0.1497
# Discriminator_loss:1.3465
#
# EPOCH[68] - STEP[100]
# Generator_loss:0.9762
# L1_loss:0.1807
# Discriminator_loss:1.1128
#
# EPOCH[68] - STEP[150]
# Generator_loss:1.9282
# L1_loss:0.1405
# Discriminator_loss:1.5398
#
# EPOCH[68] - STEP[200]
# Generator_loss:0.9896
# L1_loss:0.1767
# Discriminator_loss:0.7137
#
# EPOCH[68] - STEP[250]
# Generator_loss:0.8841
# L1_loss:0.1905
# Discriminator_loss:0.7633
#
# EPOCH[69] - STEP[50]
# Generator_loss:0.4892
# L1_loss:0.1531
# Discriminator_loss:1.6486
#
# EPOCH[69] - STEP[100]
# Generator_loss:0.9872
# L1_loss:0.2044
# Discriminator_loss:0.7191
#
# EPOCH[69] - STEP[150]
# Generator_loss:1.5303
# L1_loss:0.1803
# Discriminator_loss:0.3009
#
# EPOCH[69] - STEP[200]
# Generator_loss:1.2691
# L1_loss:0.2125
# Discriminator_loss:0.4032
#
# EPOCH[69] - STEP[250]
# Generator_loss:0.5867
# L1_loss:0.1580
# Discriminator_loss:1.4081
#
# EPOCH[70] - STEP[50]
# Generator_loss:1.4481
# L1_loss:0.1575
# Discriminator_loss:1.4121
#
# EPOCH[70] - STEP[100]
# Generator_loss:2.3317
# L1_loss:0.1933
# Discriminator_loss:0.1673
#
# EPOCH[70] - STEP[150]
# Generator_loss:1.7659
# L1_loss:0.1810
# Discriminator_loss:0.3180
#
# EPOCH[70] - STEP[200]
# Generator_loss:1.4771
# L1_loss:0.1727
# Discriminator_loss:1.0729
#
# EPOCH[70] - STEP[250]
# Generator_loss:1.4075
# L1_loss:0.1866
# Discriminator_loss:0.5092
#
# EPOCH[71] - STEP[50]
# Generator_loss:1.0745
# L1_loss:0.1743
# Discriminator_loss:0.9323
#
# EPOCH[71] - STEP[100]
# Generator_loss:0.8445
# L1_loss:0.1744
# Discriminator_loss:1.8632
#
# EPOCH[71] - STEP[150]
# Generator_loss:2.4011
# L1_loss:0.1630
# Discriminator_loss:1.9579
#
# EPOCH[71] - STEP[200]
# Generator_loss:1.3290
# L1_loss:0.1647
# Discriminator_loss:0.8007
#
# EPOCH[71] - STEP[250]
# Generator_loss:0.7055
# L1_loss:0.2228
# Discriminator_loss:0.8520
#
# EPOCH[72] - STEP[50]
# Generator_loss:2.1377
# L1_loss:0.1555
# Discriminator_loss:0.4515
#
# EPOCH[72] - STEP[100]
# Generator_loss:2.2943
# L1_loss:0.1808
# Discriminator_loss:0.2133
#
# EPOCH[72] - STEP[150]
# Generator_loss:1.5808
# L1_loss:0.2117
# Discriminator_loss:0.3055
#
# EPOCH[72] - STEP[200]
# Generator_loss:1.1758
# L1_loss:0.1585
# Discriminator_loss:3.2454
#
# EPOCH[72] - STEP[250]
# Generator_loss:0.3808
# L1_loss:0.1946
# Discriminator_loss:1.4651
#
# EPOCH[73] - STEP[50]
# Generator_loss:1.0330
# L1_loss:0.1854
# Discriminator_loss:1.4786
#
# EPOCH[73] - STEP[100]
# Generator_loss:0.6666
# L1_loss:0.2152
# Discriminator_loss:0.8956
#
# EPOCH[73] - STEP[150]
# Generator_loss:0.6684
# L1_loss:0.1620
# Discriminator_loss:1.0165
#
# EPOCH[73] - STEP[200]
# Generator_loss:2.1923
# L1_loss:0.1758
# Discriminator_loss:0.3804

# %%
EPOCHS = 200
fig = plt.figure(figsize=(13,4))
g = []
l1 = []
d = []

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
    g.append(g_loss.numpy())
    l1.append(l1_loss.numpy())
    d.append(d_loss.numpy())

epochs = range(1, len(g)+1)

ax1 = fig.add_subplot(1,3,1)
plt.plot(epochs, g, 'r', label='Generator loss')
plt.title('Generator loss')
plt.xlabel('Epochs')
plt.ylabel('g_Loss')
plt.legend()

ax2 = fig.add_subplot(1,3,2)
plt.plot(epochs, l1, 'y', label='L1 loss')
plt.title('L1 loss')
plt.xlabel('Epochs')
plt.ylabel('L1_Loss')
plt.legend()

ax3 = fig.add_subplot(1,3,3)
plt.plot(epochs, d, 'b', label='Discriminator loss')
plt.title('Discriminator loss')
plt.xlabel('Epochs')
plt.ylabel('d_Loss')
plt.legend()

# %%
test_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/val/'

for i in range(5):
    f = test_path + os.listdir(test_path)[i]
    input_image, real_image = load_img(f)

    pred = generator(tf.expand_dims(input_image, 0))
    pred = denormalize(pred)

    plt.figure(figsize=(20,10))
    plt.subplot(1,3,1); plt.imshow(denormalize(input_image)); plt.title('Input Image', fontsize=20)
    plt.subplot(1,3,2); plt.imshow(pred[0]); plt.title('Predicted Image', fontsize=20)
    plt.subplot(1,3,3); plt.imshow(denormalize(real_image)); plt.title('Ground Truth', fontsize=20)
